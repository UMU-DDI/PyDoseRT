# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch

from pydose_rt.data import MachineConfig, Phantom, Beam
from pydose_rt import DoseEngine

# %%
machine_config = MachineConfig(preset="../../src/pydose_rt/data/machine_presets/umea_10MV.json")

phantom_shape = (100, 100, 100)
phantom_resolution = (2.0, 2.0, 2.0)
phantom = Phantom.from_uniform_water(shape=phantom_shape, spacing=phantom_resolution)

device =  torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %%
beam = Beam.create(0.0, 60, 0.0, (100.0, 100.0))
beam.mu = 130 * beam.mu

phantom=phantom.to(device).to(dtype)
beam = beam.to(device).to(dtype)

dose_engine = DoseEngine(machine_config, resolution=phantom._resolution, kernel_size=101, image_template=phantom.density_image, beam_template=beam)

dose = dose_engine.compute_dose(beam, ct_image=phantom.density_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 phantom=phantom.to(device).to(dtype)
#       5 beam = beam.to(device).to(dtype)
# ----> 7 dose_engine = DoseEngine(machine_config, kernel_size=101, image_template=phantom.density_image, beam_template=beam)
#       9 dose = dose_engine.compute_dose(beam, ct_image=phantom.density_image)
#
# TypeError: DoseEngine.__init__() missing 1 required positional argument: 'resolution'

# %%
slice_idx = 84
print(dose.shape)

fig, ax = plt.subplots()
im = ax.imshow(dose[0, 50, :, :].cpu().detach().numpy(), cmap='jet', vmin=np.min(dose.cpu().detach().numpy()), vmax=np.max(dose.cpu().detach().numpy()), interpolation='nearest')


plt.suptitle(f"Dose 10cm deep: {np.round(dose[0, 50, 50, 50].detach().cpu().numpy(), 3)} Gy.")
# Add a rectangle around [25, 64]
rect = patches.Rectangle((50 - 1, 20 - 1), 1, 1, linewidth=1.5, edgecolor='white', facecolor='none')
ax.add_patch(rect)

ax.axis('off')
plt.colorbar(im, ax=ax)
plt.show()
print(f"Recommended mean avg. {machine_config.mean_photon_energy_MeV / dose[0, 50, 50, 50]}")

# %%
dose_engine.calibrate(130)
dose = dose_engine.compute_dose(beam, ct_image=phantom.density_image)

# %%
slice_idx = 84
print(dose.shape)

fig, ax = plt.subplots()
im = ax.imshow(dose[0, 50, :, :].cpu().detach().numpy(), cmap='jet', vmin=np.min(dose.cpu().detach().numpy()), vmax=np.max(dose.cpu().detach().numpy()), interpolation='nearest')


plt.suptitle(f"Dose 10cm deep: {np.round(dose[0, 50, 50, 50].detach().cpu().numpy(), 3)} Gy.")
# Add a rectangle around [25, 64]
rect = patches.Rectangle((50 - 1, 20 - 1), 1, 1, linewidth=1.5, edgecolor='white', facecolor='none')
ax.add_patch(rect)

ax.axis('off')
plt.colorbar(im, ax=ax)
plt.show()
print(f"Recommended mean avg. {machine_config.mean_photon_energy_MeV / dose[0, 50, 50, 50]}")
